# %%
import os, cv2
import numpy as np
import sys

# %%
class imagenetDataset(object):
    def __init__(self, dataPath):
        self._dataPath = dataPath
        self._epoch = 0
        self._dataStart = 0
        self._dataLength = 0
        self._dataPointPathList = None
        self._classIdxConverter = None
        self._imageSize = (480,640)
        self._loadDataPointPath()
        self._dataShuffle()
    def setImageSize(self, size=(480,640)):
        self._imageSize = size
    def _loadDataPointPath(self):
        print 'load data point path...'
        self._dataPointPathList = []
        self._classIdxConverter = dict()
        trainPath = os.path.join(self._dataPath, 'train')
        classNameList = os.listdir(trainPath)
        classNameList.sort()
        classIdx = 0
        for className in classNameList:
            classPath = os.path.join(trainPath, className)
            if os.path.isdir(classPath):
                if className not in self._classIdxConverter:
                    self._classIdxConverter[className] = classIdx
                instNameList = os.listdir(classPath)
                instNameList.sort()
                for instName in instNameList:
                    instPath = os.path.join(classPath, instName)
                    self._dataPointPathList.append(instPath)
                sys.stdout.write('{:04d}/{:04d}\r'.format(classIdx+1, 1000))
                classIdx += 1
        self._dataLength = len(self._dataPointPathList)
        print 'done!'
    def _dataShuffle(self):
        'data list shuffle...'
        self._dataStart = 0
        np.random.shuffle(self._dataPointPathList)
        print 'done!'
    def getNextBatch(self, batchSize=32):
        if self._dataStart + batchSize >=self._dataLength:
            self._epoch += 1
            self._dataStart = 0
            self._dataShuffle()
        dataStart = self._dataStart
        dataEnd = dataStart + batchSize
        dataPathTemp = self._dataPointPathList[dataStart:dataEnd]
        inputImages = []
        classIndexList = []
        for i in range(len(dataPathTemp)):
            imagePath = dataPathTemp[i]
            className = imagePath.split("/")[-2]
            classIdx = self._classIdxConverter[className]
            classIndexVector = np.zeros(1000)
            classIndexVector[classIdx] = 1
            classIndexList.append(classIndexVector)
            
            image = cv2.imread(imagePath, cv2.IMREAD_COLOR)
            image = cv2.resize(image, self._imageSize)
            inputImages.append(image)
            
        batchData = {
            'inputImages':np.array(inputImages).astype('float'),
            'classIndexList':np.array(classIndexList).astype('float')
        }
        return batchData

# %%
fuck = imagenetDataset(dataPath = '/media/yonsei/4TB_HDD/dataset/ImageNet/')
fuck.setImageSize((224,224))
# Out:
# 1000/1000

# %%
batchData = fuck.getNextBatch(32)

# %%
inputImages = batchData['inputImages']
classIndexList = batchData['classIndexList']
for i in range(len(inputImages)):
    image = inputImages[i]
    classIndex = classIndexList[i]
    cv2.imwrite('test/'+str(i)+'.jpg', image)
    print np.argmax(classIndex)
# Out:
# 180
# 629
# 991
# 92
# 676
# 95
# 115
# 260
# 597
# 981
# 11
# 718
# 688
# 477
# 852
# 692
# 133
# 225
# 301
# 871
# 738
# 363
# 680
# 0
# 845
# 847
# 927
# 337
# 297
# 887
# 465
# 708

# %%
dataPath_ObjectNet3D = "/media/yonsei/4TB_HDD/dataset/ObjectNet3D/"
dataPath_Pascal3D = "/media/yonsei/4TB_HDD/dataset/PASCAL3D+_release1.1/"
dataPath_pix3D = "/media/yonsei/4TB_HDD/dataset/pix3d/"

# %%
classDict = {
    'aeroplane' : 1, 'bed' : 2, 'bench' : 3, 'bicycle' : 4, 'boat' : 5, 'bookshelf' : 6, 'bottle' : 7, 'bus' : 8, 'cabinet' : 9, 'can' : 10,
    'car' : 11, 'chair' : 12, 'computer' : 13, 'cup' : 14, 'desk' : 15, 'table' : 16, 'door' : 17, 'cabinet' : 18, 'fire_extinguiser' : 19, 'keyboard' : 20,
    'laptop' : 21, 'motorbike':22, 'microwave':23, 'mouse':24, 'piano':25, 'refrigerator':26, 'sofa':27, 'toilet':28, 'train':29, 'bathtub':30,
    'tvmonitor':31, 'wardrobe':32
}

# %%
classConvertion = {
    'aeroplane' : 'aeroplane',
    'bed' : 'bed',
    'bench' : 'bench',
    'bicycle' : 'bicycle',
    'boat' : 'boat',
    'bookshelf' : 'bookshelf',
    'bookcase' : 'bookshelf',
    'bottle' : 'bottle',
    'bus' : 'bus',
    'cabinet' : 'cabinet',
    'can' : 'can',
    'car' : 'car',
    'chair' : 'chair',
    'computer' : 'computer',
    'cup' : 'cup',
    'desk' : 'desk',
    'diningtable' : 'table',
    'door' : 'door',
    'filing_cabinet' : 'cabinet',
    'fire_extinguisher' : 'fire_extinguiser',
    'jar' : 'bottle',
    'keyboard' : 'keyboard',
    'laptop' : 'laptop',
    'motorbike' : 'motorbike',
    'microwave' : 'microwave',
    'mouse' : 'mouse',
    'piano' : 'piano',
    'refrigerator' : 'refrigerator',
    'sofa' : 'sofa',
    'table' : 'table',
    'toilet' : 'toilet',
    'train' : 'train',
    'tub' : 'bathtub',
    'tvmonitor' : 'tvmonitor',
    'wardrobe' : 'wardrobe'
}

# %%
instDict_ObjectNet3D = dict()
instDict_pix3D = dict()

# %%
classList = os.listdir(os.path.join(dataPath_ObjectNet3D, 'CAD'))
for orgClassName in classList:
    if os.path.isdir(os.path.join(dataPath_ObjectNet3D, 'CAD', orgClassName)):
        if orgClassName in classConvertion:
            className = classConvertion[orgClassName]
            classIdx = classDict[className]
            print classIdx, className
            if className not in instDict_ObjectNet3D:
                instDict_ObjectNet3D[className] = dict()
            CADModelList = os.listdir(os.path.join(dataPath_ObjectNet3D, 'CAD', orgClassName))
            CADModelList.sort()
            instIdx = 1
            for CADModel in CADModelList:
                if CADModel.endswith(".pcd"):
                    CADModelPath = os.path.join('CAD', orgClassName, CADModel.split('.')[0])
                    if CADModelPath not in instDict_ObjectNet3D[className]:
                        instDict_ObjectNet3D[className][CADModelPath] = instIdx
                        instIdx += 1
# Out:
# 12 chair
# 25 piano
# 1 aeroplane
# 2 bed
# 3 bench
# 4 bicycle
# 5 boat
# 6 bookshelf
# 7 bottle
# 8 bus
# 18 cabinet
# 10 can
# 11 car
# 13 computer
# 14 cup
# 16 table
# 17 door
# 18 cabinet
# 19 fire_extinguiser
# 7 bottle
# 20 keyboard
# 21 laptop
# 23 microwave
# 22 motorbike
# 24 mouse
# 26 refrigerator
# 27 sofa
# 28 toilet
# 29 train
# 30 bathtub
# 31 tvmonitor

# %%
for key in instDict_ObjectNet3D.keys():
    print key
    for subKey in instDict_ObjectNet3D[key].keys():
        print subKey, instDict_ObjectNet3D[key][subKey]
# Out:
# fire_extinguiser
# CAD/fire_extinguisher/08 8
# CAD/fire_extinguisher/09 9
# CAD/fire_extinguisher/02 2
# CAD/fire_extinguisher/03 3
# CAD/fire_extinguisher/01 1
# CAD/fire_extinguisher/06 6
# CAD/fire_extinguisher/07 7
# CAD/tub/06 6

# %%
classList = os.listdir(os.path.join(dataPath_pix3D, 'model'))
for orgClassName in classList:
    if os.path.isdir(os.path.join(dataPath_pix3D, 'model', orgClassName)):
        if orgClassName in classConvertion:
            className = classConvertion[orgClassName]
            classIdx = classDict[className]
            print classIdx, className
            if className not in instDict_pix3D:
                instDict_pix3D[className] = dict()
            instIdx = 1
            for path, dirs, files in os.walk(os.path.join(dataPath_pix3D, 'model', orgClassName)):
                files.sort()
                for fileName in files:
                    if fileName.endswith('.pcd'):
                        filePath = os.path.join('model', orgClassName, path.split('/')[-1], fileName.split('.')[0])
                        if filePath not in instDict_pix3D[className]:
                            instDict_pix3D[className][filePath] = instIdx
                            instIdx += 1
# Out:
# 2 bed
# 6 bookshelf
# 12 chair
# 15 desk
# 27 sofa
# 16 table
# 32 wardrobe

# %%
for key in instDict_pix3D.keys():
    print key
    for subKey in instDict_pix3D[key].keys():
        print subKey, instDict_pix3D[key][subKey]
# Out:
# sofa
# model/sofa/IKEA_VRETA/model 20
# model/sofa/IKEA_SKOGABY/model 17
# model/sofa/IKEA_SOLSTA_d053e745b565fa391c1b3b2ed8d13bf8/model 18
# model/sofa/IKEA_KIVIK_2/model 9
# model/sofa/IKEA_KARLSTAD_4/model 7
# model/sofa/IKEA_SATER/model 16
# model/sofa/IKEA_KARLSTAD_2/model 5
# model/sofa/IKEA_TIDAFORS/model 19
# model/sofa/IKEA_EKTORP_3/model 3
# model/sofa/IKEA_KLIPPAN_3/model 13
# model/sofa/IKEA_KLAPPSTA/model 10
# model/sofa/IKEA_KIVIK_1/model 8
# model/sofa/IKEA_LYCKSELE/model 14
# model/sofa/IKEA_KARLSTAD_1/model 4
# model/sofa/IKEA_KLIPPAN_2/model 12
# model/sofa/IKEA_EKTORP_2/model 2
# model/sofa/IKEA_EKTORP_1/model 1
# model/sofa/IKEA_KLIPPAN_1/model 11
# model/sofa/IKEA_MANSTAD/model 15
# model/sofa/IKEA_KARLSTAD_3/model 6
# bed
# model/bed/IKEA_FJELLSE_1/model 5
# model/bed/IKEA_LEIRVIK/model 10
# model/bed/IKEA_FJELLSE_2/model 6
# model/bed/IKEA_MANDAL_2/model 17
# model/bed/IKEA_LILLESAND/model 11
# model/bed/IKEA_BEDDINGE/model 1
# model/bed/IKEA_MALM_1/model 12
# model/bed/IKEA_BRIMNES_1/model 2
# model/bed/IKEA_BRIMNES_2/model 3
# model/bed/IKEA_HEMNES_1/model 7
# model/bed/IKEA_TROMSO/model 19
# model/bed/IKEA_BRIMNES_3/model 4
# model/bed/IKEA_MALM_3/model 14
# model/bed/IKEA_MALM_4/model 15
# model/bed/IKEA_VANVIK/model 20
# model/bed/IKEA_MANDAL_1/model 16
# model/bed/IKEA_NORDLI/model 18
# model/bed/IKEA_HEMNES_3/model 9
# model/bed/IKEA_MALM_2/model 13
# model/bed/IKEA_HEMNES_2/model 8
# wardrobe
# model/wardrobe/IKEA_DOMBAS/model 3
# model/wardrobe/IKEA_PAX_1/model 7
# model/wardrobe/IKEA_ODDA_1/model 5
# model/wardrobe/IKEA_PAX_3/model 9
# model/wardrobe/IKEA_ODDA_2/model 6
# model/wardrobe/IKEA_PAX_4/model 10
# model/wardrobe/IKEA_ANEBODA_1/model 1
# model/wardrobe/IKEA_ANEBODA_2/model 2
# model/wardrobe/IKEA_HEMNES/model 4
# model/wardrobe/IKEA_PAX_2/model 8
# desk
# model/desk/IKEA_VIKA_2/model 21
# model/desk/IKEA_GALANT_2/model 8
# model/desk/IKEA_GALANT_6/model 12
# model/desk/IKEA_BESTA_1/model 1
# model/desk/IKEA_BESTA_2/model 2
# model/desk/IKEA_HEMNES/model 13
# model/desk/IKEA_MALM/model 17
# model/desk/IKEA_EXPEDIT_2/model 4
# model/desk/IKEA_GALANT_5/model 11
# model/desk/IKEA_LEKSVIK/model 15
# model/desk/IKEA_GALANT_3/model 9
# model/desk/IKEA_MICKE_1/model 18
# model/desk/IKEA_FREDRIK/model 6
# model/desk/IKEA_VITTSJO/model 23
# model/desk/IKEA_LIATORP/model 16
# model/desk/IKEA_EXPEDIT_1/model 3
# model/desk/IKEA_VIKA_1/model 20
# model/desk/IKEA_MICKE_2/model 19
# model/desk/IKEA_EXPEDIT_3/model 5
# model/desk/IKEA_GALANT_1/model 7
# model/desk/IKEA_LAIVA/model 14
# model/desk/IKEA_VIKA_3/model 22
# model/desk/IKEA_GALANT_4/model 10
# bookshelf
# model/bookcase/IKEA_BILLY_5/model 6
# model/bookcase/IKEA_BESTA/model 1
# model/bookcase/IKEA_LAIVA/model 17
# model/bookcase/IKEA_BILLY_4/model 5
# model/bookcase/IKEA_KILBY_1/model 12
# model/bookcase/IKEA_LACK_2/model 15
# model/bookcase/IKEA_HEMNES/model 11
# model/bookcase/IKEA_EXPEDIT_2/model 9
# model/bookcase/IKEA_EXPEDIT_1/model 8
# model/bookcase/IKEA_LACK_1/model 14
# model/bookcase/IKEA_BILLY_3/model 4
# model/bookcase/IKEA_BILLY_6/model 7
# model/bookcase/IKEA_KILBY_2/model 13
# model/bookcase/IKEA_EXPEDIT_3/model 10
# model/bookcase/IKEA_BILLY_1/model 2
# model/bookcase/IKEA_LACK_3/model 16
# model/bookcase/IKEA_BILLY_2/model 3
# table
# model/table/IKEA_MALM_3/model 42
# model/table/IKEA_FUSION/model 12
# model/table/IKEA_LINDVED/model 39
# model/table/IKEA_MALM_1/model 40
# model/table/IKEA_NORDEN_1/model 46
# model/table/IKEA_BOKSEL_2/model 10
# model/table/IKEA_BJORKUDDEN_1/model 3
# model/table/IKEA_INGO_4/model 23
# model/table/IKEA_UTBY_2/model 58
# model/table/IKEA_TORSBY_2/model 56
# model/table/IKEA_INGO_1/model 20
# model/table/IKEA_NORDLI/model 49
# model/table/IKEA_BJURSTA_3/model 8
# model/table/IKEA_BJORKUDDEN_2/model 4
# model/table/IKEA_KLINGSBO_1/model 27
# model/table/IKEA_BJORKUDDEN_3/model 5
# model/table/IKEA_LACK_3/model 36
# model/table/IKEA_KLUBBO_4/model 1
# model/table/IKEA_SALMI/model 53
# model/table/IKEA_KLUBBO_5/model 32
# model/table/IKEA_KLUBBO_2/model 30
# model/table/IKEA_BOKSEL_1/model 9
# model/table/IKEA_TOFTERYD/model 54
# model/table/IKEA_LACK_1/model 34
# model/table/IKEA_INGATORP/model 19
# model/table/IKEA_INGO_2/model 21
# model/table/IKEA_TORSBY_1/model 55
# model/table/IKEA_INGO_3/model 22
# model/table/IKEA_KLUBBO_6/model 33
# model/table/IKEA_ISALA_1/model 24
# model/table/IKEA_BJURSTA_2/model 7
# model/table/IKEA_HEMNES_5/model 18
# model/table/IKEA_NESNA/model 44
# model/table/IKEA_GRANAS/model 13
# model/table/IKEA_MUDDUS/model 43
# model/table/IKEA_UTBY_1/model 57
# model/table/IKEA_NORBO/model 45
# model/table/IKEA_BJURSTA_1/model 6
# model/table/IKEA_HEMNES_2/model 15
# model/table/IKEA_LACK_2/model 35
# model/table/IKEA_VEJMON_1/model 59
# model/table/IKEA_NORDEN_3/model 48
# model/table/IKEA_ISALA_2/model 25
# model/table/IKEA_NORDEN_2/model 47
# model/table/IKEA_LIATORP_1/model 37
# model/table/IKEA_VITTSJO_2/model 63
# model/table/IKEA_DOCKSTA/model 11
# model/table/IKEA_RAST/model 52
# model/table/IKEA_HEMNES_4/model 17
# model/table/IKEA_VEJMON_2/model 60
# model/table/IKEA_HEMNES_3/model 16
# model/table/IKEA_KLUBBO_3/model 31
# model/table/IKEA_LIATORP_2/model 38
# model/table/IKEA_MALM_2/model 41
# model/table/IKEA_JOKKMOKK/model 26
# model/table/IKEA_KLUBBO_1/model 29
# model/table/IKEA_VITTSJO_1/model 62
# model/table/IKEA_BIRKELAND/model 2
# model/table/IKEA_HEMNES_1/model 14
# model/table/IKEA_ODDA/model 51
# model/table/IKEA_KLINGSBO_2/model 28
# model/table/IKEA_VEJMON_3/model 61
# model/table/IKEA_NYVOLL/model 50
# chair
# model/chair/SS_032/model 73
# model/chair/SS_183/model 187
# model/chair/SS_100/model 64
# model/chair/SS_141/model 101
# model/chair/SS_166/model 170
# model/chair/SS_134/model 94
# model/chair/SS_185/model 189
# model/chair/SS_155/model 115
# model/chair/IKEA_SNILLE_1/model_1 156
# model/chair/IKEA_SOLSTA_OLARP/model 119
# model/chair/IKEA_PATRIK/model_0 31
# model/chair/IKEA_BORJE/model 2
# model/chair/IKEA_SNILLE_1/model_-0 151
# model/chair/IKEA_SNILLE_1/model_-1 152
# model/chair/SS_164/model 168
# model/chair/SS_055/model 220
# model/chair/SS_085/model 49
# model/chair/IKEA_SNILLE_1/model_-7 154
# model/chair/IKEA_MARKUS/model_-0 24
# model/chair/IKEA_MARKUS/model_-1 25
# model/chair/SS_115/model 201
# model/chair/IKEA_REIDAR/model 35
# model/chair/IKEA_NILS/model 29
# model/chair/SS_103/model 67
# model/chair/SS_176/model 180
# model/chair/SS_089/model 53
# model/chair/SS_023/model 148
# model/chair/SS_016/model 141
# model/chair/SS_107/model 193
# model/chair/SS_132/model 92
# model/chair/SS_180/model 184
# model/chair/SS_028/model 69
# model/chair/SS_026/model 157
# model/chair/IKEA_URBAN/model 122
# model/chair/SS_066/model 231
# model/chair/SS_045/model 86
# model/chair/SS_099/model 63
# model/chair/IKEA_HENRIKSDAL/model 7
# model/chair/SS_173/model 177
# model/chair/SS_006/model 131
# model/chair/IKEA_POANG_2/model 33
# model/chair/SS_020/model 145
# model/chair/SS_096/model 60
# model/chair/IKEA_JULES_2/model 19
# model/chair/SS_010/model 135
# model/chair/SS_012/model 137
# model/chair/SS_072/model 237
# model/chair/IKEA_STEFAN/model 120
# model/chair/SS_090/model 54
# model/chair/SS_149/model 109
# model/chair/SS_128/model 214
# model/chair/SS_121/model 207
# model/chair/IKEA_JULES_1/model_1 17
# model/chair/IKEA_JULES_1/model_0 16
# model/chair/SS_108/model 194
# model/chair/SS_150/model 110
# model/chair/SS_005/model 130
# model/chair/SS_097/model 61
# model/chair/SS_162/model 166
# model/chair/SS_129/model 215
# model/chair/SS_035/model 76
# model/chair/SS_008/model 133
# model/chair/SS_186/model 190
# model/chair/SS_169/model 173
# model/chair/SS_063/model 228
# model/chair/SS_018/model 143
# model/chair/SS_078/model 42
# model/chair/SS_039/model 80
# model/chair/IKEA_FUSION/model 6
# model/chair/SS_140/model 100
# model/chair/IKEA_KLAPPSTA_2/model 22
# model/chair/SS_133/model 93
# model/chair/SS_002/model 127
# model/chair/IKEA_PREBEN/model 34
# model/chair/SS_022/model 147
# model/chair/SS_160/model 164
# model/chair/IKEA_INGOLF/model 9
# model/chair/SS_142/model 102
# model/chair/SS_161/model 165
# model/chair/SS_139/model 99
# model/chair/SS_179/model 183
# model/chair/SS_062/model 227
# model/chair/SS_019/model 144
# model/chair/IKEA_SNILLE_2/model 118
# model/chair/SS_118/model 204
# model/chair/SS_113/model 199
# model/chair/SS_111/model 197
# model/chair/SS_065/model 230
# model/chair/SS_135/model 95
# model/chair/SS_117/model 203
# model/chair/SS_148/model 108
# model/chair/IKEA_VRETA/model 125
# model/chair/IKEA_JULES_1/model_24 18
# model/chair/SS_001/model 126
# model/chair/IKEA_JULES_1/model_-108 14
# model/chair/SS_074/model 239
# model/chair/SS_156/model 116
# model/chair/IKEA_SKRUVSTA/model_-0 37
# model/chair/SS_040/model 81
# model/chair/SS_027/model 68
# model/chair/IKEA_SKRUVSTA/model_-6 38
# model/chair/SS_004/model 129
# model/chair/SS_120/model 206
# model/chair/SS_125/model 211
# model/chair/SS_163/model 167
# model/chair/SS_025/model 150
# model/chair/SS_046/model 87
# model/chair/SS_158/model 162
# model/chair/SS_036/model 77
# model/chair/SS_093/model 57
# model/chair/IKEA_JULES_1/model_-1 13
# model/chair/IKEA_JULES_1/model_-0 12
# model/chair/SS_159/model 163
# model/chair/IKEA_JULES_1/model_-6 15
# model/chair/SS_106/model 192
# model/chair/SS_082/model 46
# model/chair/IKEA_IVAR/model 10
# model/chair/IKEA_EKTORP_2/model 5
# model/chair/IKEA_EKTORP_1/model 4
# model/chair/SS_070/model 235
# model/chair/SS_144/model 104
# model/chair/IKEA_SNILLE_1/model_-31 153
# model/chair/SS_068/model 233
# model/chair/SS_181/model 185
# model/chair/SS_086/model 50
# model/chair/SS_011/model 136
# model/chair/SS_157/model 117
# model/chair/SS_092/model 56
# model/chair/SS_053/model 218
# model/chair/SS_038/model 79
# model/chair/SS_058/model 223
# model/chair/IKEA_HERMAN/model 8
# model/chair/SS_119/model 205
# model/chair/SS_037/model 78
# model/chair/SS_044/model 85
# model/chair/SS_146/model 106
# model/chair/SS_033/model 74
# model/chair/SS_084/model 48
# model/chair/SS_147/model 107
# model/chair/IKEA_VILMAR_2/model 124
# model/chair/SS_003/model 128
# model/chair/IKEA_BERNHARD/model 1
# model/chair/SS_153/model 113
# model/chair/IKEA_SKRUVSTA/model_0 39
# model/chair/IKEA_SKRUVSTA/model_1 40
# model/chair/SS_101/model 65
# model/chair/SS_083/model 47
# model/chair/IKEA_SKRUVSTA/model_5 41
# model/chair/SS_069/model 234
# model/chair/SS_091/model 55
# model/chair/IKEA_PATRIK/model_-0 30
# model/chair/SS_151/model 111
# model/chair/SS_024/model 149
# model/chair/IKEA_SIGURD/model 36
# model/chair/SS_116/model 202
# model/chair/SS_030/model 71
# model/chair/SS_171/model 175
# model/chair/IKEA_TOBIAS/model 121
# model/chair/SS_178/model 182
# model/chair/SS_095/model 59
# model/chair/SS_034/model 75
# model/chair/SS_007/model 132
# model/chair/SS_075/model 240
# model/chair/IKEA_SNILLE_1/model_0 155
# model/chair/SS_041/model 82
# model/chair/SS_127/model 213
# model/chair/SS_152/model 112
# model/chair/SS_145/model 105
# model/chair/SS_021/model 146
# model/chair/SS_105/model 191
# model/chair/SS_043/model 84
# model/chair/SS_172/model 176
# model/chair/SS_104/model 160
# model/chair/SS_182/model 186
# model/chair/SS_112/model 198
# model/chair/IKEA_KAUSTBY/model 20
# model/chair/SS_102/model 66
# model/chair/SS_077/model 159
# model/chair/SS_054/model 219
# model/chair/SS_098/model 62
# model/chair/SS_165/model 169
# model/chair/SS_060/model 225
# model/chair/SS_064/model 229
# model/chair/SS_049/model 90
# model/chair/IKEA_POANG_1/model 32
# model/chair/IKEA_JOKKMOKK/model 11
# model/chair/SS_014/model 139
# model/chair/IKEA_MARIUS/model 23
# model/chair/SS_131/model 161
# model/chair/SS_167/model 171
# model/chair/SS_015/model 140
# model/chair/SS_052/model 217
# model/chair/SS_088/model 52
# model/chair/SS_031/model 72
# model/chair/SS_061/model 226
# model/chair/SS_136/model 96
# model/chair/SS_170/model 174
# model/chair/SS_059/model 224
# model/chair/SS_138/model 98
# model/chair/SS_050/model 91
# model/chair/SS_051/model 158
# model/chair/SS_029/model 70
# model/chair/SS_130/model 216
# model/chair/SS_079/model 43
# model/chair/SS_154/model 114
# model/chair/SS_087/model 51
# model/chair/SS_017/model 142
# model/chair/SS_137/model 97
# model/chair/SS_042/model 83
# model/chair/SS_067/model 232
# model/chair/SS_184/model 188
# model/chair/SS_174/model 178
# model/chair/SS_009/model 134
# model/chair/IKEA_MARKUS/model_4 28
# model/chair/IKEA_MARKUS/model_0 26
# model/chair/IKEA_MARKUS/model_1 27
# model/chair/IKEA_EKENAS/model 3
# model/chair/SS_122/model 208
# model/chair/SS_081/model 45
# model/chair/SS_175/model 179
# model/chair/SS_109/model 195
# model/chair/SS_071/model 236
# model/chair/SS_048/model 89
# model/chair/SS_076/model 241
# model/chair/SS_073/model 238
# model/chair/SS_057/model 222
# model/chair/SS_047/model 88
# model/chair/SS_177/model 181
# model/chair/SS_168/model 172
# model/chair/SS_123/model 209
# model/chair/SS_080/model 44
# model/chair/SS_094/model 58
# model/chair/SS_114/model 200
# model/chair/SS_124/model 210
# model/chair/SS_143/model 103
# model/chair/SS_126/model 212
# model/chair/IKEA_KLAPPSTA_1/model 21
# model/chair/SS_056/model 221
# model/chair/IKEA_VILMAR_1/model 123
# model/chair/SS_013/model 138
# model/chair/SS_110/model 196
